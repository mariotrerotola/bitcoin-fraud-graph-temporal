# %%
"""
Synthetic Data Augmentation, Student NN & Rule Extraction
========================================================

Workflow:

1. **Teacher** Random Forest on the original train split.
2. **SMOTE** synthetic generation up to `TARGET_TOTAL` samples.
3. **Self‑label** synthetic data with the teacher and keep only high-confidence
   points (≥ `CONF_THRESH`).
4. Merge original + synthetic data → train **MLP student**.
5. Evaluate the student on the untouched test split.
6. **DEXiRE** rule extraction from the trained student for symbolic
   interpretability, with a prettified mapping of feature indices to names.
"""
# Out:
# '\nSynthetic Data Augmentation, Student NN & Rule Extraction\n========================================================\n\nWorkflow:\n\n1. **Teacher** Random Forest on the original train split.\n2. **SMOTE** synthetic generation up to `TARGET_TOTAL` samples.\n3. **Self‑label** synthetic data with the teacher and keep only high-confidence\n   points (≥\xa0`CONF_THRESH`).\n4. Merge original + synthetic data → train **MLP student**.\n5. Evaluate the student on the untouched test split.\n6. **DEXiRE** rule extraction from the trained student for symbolic\n   interpretability, with a prettified mapping of feature indices to names.\n'

# %%
# ----------------------------------------------------------------------
# Parameters & reproducibility
# ----------------------------------------------------------------------
from __future__ import annotations

import os
import random
from pathlib import Path
import re

import numpy as np
import pandas as pd
from imblearn.over_sampling import SMOTE
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from tensorflow.keras import callbacks, layers, models, optimizers
from tensorflow.keras.utils import to_categorical

from dexire.dexire import DEXiRE  # pip install dexire
import os
from pathlib import Path
import warnings

SEED           = 42
CONF_THRESH    = 0.90       # teacher confidence threshold
TEST_SIZE      = 0.20
TARGET_TOTAL   = 2_000_000  # reduce to 2M for demo; adjust as needed
DATA_PATH      = Path(os.getenv(
    "DATASET_PATH",
    "../../data/processed_data/case_3.csv",
))
random.seed(SEED)
np.random.seed(SEED)
os.environ["PYTHONHASHSEED"] = str(SEED)

# %%
# ----------------------------------------------------------------------
# 1⃣  Load dataset & split
# ----------------------------------------------------------------------
if not DATA_PATH.exists():
    raise FileNotFoundError(f"Dataset not found → {DATA_PATH.resolve()}")

print("[INFO] Loading dataset …")
df = pd.read_csv(DATA_PATH)
X = df.drop(columns=["class"]).values
feature_names = df.drop(columns=["class"]).columns  # keep for DEXiRE

y = df["class"].values
le = LabelEncoder()
y_enc = le.fit_transform(y)

X_train, X_test, y_train, y_test = train_test_split(
    X, y_enc, test_size=TEST_SIZE, stratify=y_enc, random_state=SEED
)
print(f"[INFO] Original train distribution: {np.bincount(y_train)}\n")
# Out:
# [INFO] Loading dataset …
# [INFO] Original train distribution: [5074 5722]

# %%
# ----------------------------------------------------------------------
# 2⃣  Train teacher Random Forest
# ----------------------------------------------------------------------
print("[INFO] Training RandomForest teacher …")
rf = RandomForestClassifier(
    n_estimators=800,
    class_weight="balanced",
    n_jobs=-1,
    random_state=SEED,
)
rf.fit(X_train, y_train)
print("[INFO] Teacher trained.\n")
# Out:
# [INFO] Training RandomForest teacher …
# [INFO] Teacher trained.

# %%
# ----------------------------------------------------------------------
# 3⃣  SMOTE synthetic generation & filtering
# ----------------------------------------------------------------------
classes           = np.unique(y_train)
per_class_target  = TARGET_TOTAL // len(classes)
smote_strategy    = {cls: per_class_target for cls in classes}
print(f"[INFO] SMOTE target per class: {smote_strategy}")

smote  = SMOTE(sampling_strategy=smote_strategy, random_state=SEED)
print("[INFO] Generating synthetic samples …")
X_syn_full, _ = smote.fit_resample(X_train, y_train)
synthetic_count = X_syn_full.shape[0] - X_train.shape[0]
X_syn = X_syn_full[-synthetic_count:]

print("[INFO] Teacher self‑labelling & confidence filter …")
proba_syn = rf.predict_proba(X_syn)
conf_max  = proba_syn.max(axis=1)
y_syn_lbl = proba_syn.argmax(axis=1)

mask_conf   = conf_max >= CONF_THRESH
X_syn_filt  = X_syn[mask_conf]
y_syn_filt  = y_syn_lbl[mask_conf]
print(f"[INFO] High‑confidence synthetic kept: {len(y_syn_filt)} / {synthetic_count}\n")
# Out:
# [INFO] SMOTE target per class: {0: 1000000, 1: 1000000}
# [INFO] Generating synthetic samples …
# [INFO] Teacher self‑labelling & confidence filter …
# [INFO] High‑confidence synthetic kept: 1183679 / 1989204

# %%
# ----------------------------------------------------------------------
# 4⃣  Merge & shuffle
# ----------------------------------------------------------------------
X_comb = np.vstack([X_train, X_syn_filt])
y_comb = np.concatenate([y_train, y_syn_filt])
perm    = np.random.permutation(len(y_comb))
X_comb, y_comb = X_comb[perm], y_comb[perm]
print(f"[INFO] Final train size: {X_comb.shape}, distribution: {np.bincount(y_comb)}\n")
# Out:
# [INFO] Final train size: (1194475, 21), distribution: [537996 656479]

# %%
# ----------------------------------------------------------------------
# 5⃣  Scale & one‑hot labels
# ----------------------------------------------------------------------
scaler = StandardScaler()
X_comb_s = scaler.fit_transform(X_comb)
X_test_s = scaler.transform(X_test)

y_comb_o = to_categorical(y_comb)
y_test_o = to_categorical(y_test)

# %%
# ----------------------------------------------------------------------
# 6⃣  Build + train student MLP
# ----------------------------------------------------------------------
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping

# ipotesi: X_train, y_train, X_val, y_val, X_test, y_test sono già pronti
# e class_weight è definito se vuoi bilanciare le classi

# 1. Costruzione del modello



def build_student(input_dim: int, output_dim: int):
    model = Sequential([
        Dense(128, activation='relu', input_shape=(input_dim,)),
        # Dropout(0.3),
        Dense(64, activation='relu'),
        # Dropout(0.3),
        Dense(32, activation='relu'),
        # Dropout(0.3),
        Dense(output_dim, activation='sigmoid')
    ])
    model.compile(optimizer=optimizers.Adam(1e-3), loss="categorical_crossentropy", metrics=["accuracy"])
    return model

print("[INFO] Training student MLP …")
student = build_student(X_comb_s.shape[1], y_comb_o.shape[1])
cb_es = callbacks.EarlyStopping(monitor="val_loss", patience=10, restore_best_weights=True)
cb_lr = callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=5)
student.fit(
    X_comb_s,
    y_comb_o,
    validation_split=0.2,
    epochs=30,
    batch_size=1024,
    callbacks=[cb_es, cb_lr],
    verbose=1,
)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# [INFO] Training student MLP …
# Epoch 1/30
# 934/934 [==============================] - 2s 2ms/step - loss: 0.1240 - accuracy: 0.9674 - val_loss: 0.0619 - val_accuracy: 0.9800 - lr: 0.0010
# Epoch 2/30
# 934/934 [==============================] - 1s 1ms/step - loss: 0.0688 - accuracy: 0.9809 - val_loss: 0.0556 - val_accuracy: 0.9821 - lr: 0.0010
# Epoch 3/30
# 934/934 [==============================] - 1s 1ms/step - loss: 0.0542 - accuracy: 0.9834 - val_loss: 0.0567 - val_accuracy: 0.9835 - lr: 0.0010
# Epoch 4/30
# 934/934 [==============================] - 1s 1ms/step - loss: 0.0492 - accuracy: 0.9845 - val_loss: 0.0442 - val_accuracy: 0.9855 - lr: 0.0010
# Epoch 5/30
# 934/934 [==============================] - 1s 2ms/step - loss: 0.0442 - accuracy: 0.9855 - val_loss: 0.0416 - val_accuracy: 0.9855 - lr: 0.0010
# Epoch 6/30
# 934/934 [==============================] - 1s 2ms/step - loss: 0.0427 - accuracy: 0.9861 - val_loss: 0.0440 - val_accuracy: 0.9858 - lr: 0.0010
# Epoch 7/30
# 934/934 [==============================] - 1s 2ms/step - loss: 0.0400 - accuracy: 0.9869 - val_loss: 0.0415 - val_accuracy: 0.9879 - lr: 0.0010
# Epoch 8/30
# 934/934 [==============================] - 1s 2ms/step - loss: 0.0379 - accuracy: 0.9875 - val_loss: 0.0359 - val_accuracy: 0.9876 - lr: 0.0010
# Epoch 9/30
# 934/934 [==============================] - 2s 2ms/step - loss: 0.0367 - accuracy: 0.9879 - val_loss: 0.0359 - val_accuracy: 0.9879 - lr: 0.0010
# Epoch 10/30
# 934/934 [==============================] - 2s 2ms/step - loss: 0.0352 - accuracy: 0.9883 - val_loss: 0.0386 - val_accuracy: 0.9878 - lr: 0.0010
# Epoch 11/30
# 934/934 [==============================] - 2s 2ms/step - loss: 0.0331 - accuracy: 0.9890 - val_loss: 0.0324 - val_accuracy: 0.9887 - lr: 0.0010
# Epoch 12/30
# 934/934 [==============================] - 2s 2ms/step - loss: 0.0325 - accuracy: 0.9892 - val_loss: 0.0375 - val_accuracy: 0.9880 - lr: 0.0010
# Epoch 13/30
# 934/934 [==============================] - 2s 2ms/step - loss: 0.0312 - accuracy: 0.9896 - val_loss: 0.0348 - val_accuracy: 0.9885 - lr: 0.0010
# Epoch 14/30
# 934/934 [==============================] - 2s 2ms/step - loss: 0.0301 - accuracy: 0.9901 - val_loss: 0.0277 - val_accuracy: 0.9913 - lr: 0.0010
# Epoch 15/30
# 934/934 [==============================] - 2s 2ms/step - loss: 0.0292 - accuracy: 0.9903 - val_loss: 0.0393 - val_accuracy: 0.9872 - lr: 0.0010
# Epoch 16/30
# 934/934 [==============================] - 2s 2ms/step - loss: 0.0290 - accuracy: 0.9906 - val_loss: 0.0572 - val_accuracy: 0.9747 - lr: 0.0010
# Epoch 17/30
# 934/934 [==============================] - 1s 2ms/step - loss: 0.0279 - accuracy: 0.9909 - val_loss: 0.0263 - val_accuracy: 0.9920 - lr: 0.0010
# Epoch 18/30
# 934/934 [==============================] - 1s 2ms/step - loss: 0.0267 - accuracy: 0.9912 - val_loss: 0.0250 - val_accuracy: 0.9920 - lr: 0.0010
# Epoch 19/30
# 934/934 [==============================] - 2s 2ms/step - loss: 0.0269 - accuracy: 0.9913 - val_loss: 0.0344 - val_accuracy: 0.9883 - lr: 0.0010
# Epoch 20/30
# 934/934 [==============================] - 1s 2ms/step - loss: 0.0255 - accuracy: 0.9917 - val_loss: 0.0247 - val_accuracy: 0.9920 - lr: 0.0010
# Epoch 21/30
# 934/934 [==============================] - 1s 2ms/step - loss: 0.0258 - accuracy: 0.9917 - val_loss: 0.0239 - val_accuracy: 0.9924 - lr: 0.0010
# Epoch 22/30
# 934/934 [==============================] - 2s 2ms/step - loss: 0.0248 - accuracy: 0.9919 - val_loss: 0.0335 - val_accuracy: 0.9887 - lr: 0.0010
# Epoch 23/30
# 934/934 [==============================] - 2s 2ms/step - loss: 0.0248 - accuracy: 0.9921 - val_loss: 0.0266 - val_accuracy: 0.9911 - lr: 0.0010
# Epoch 24/30
# 934/934 [==============================] - 2s 2ms/step - loss: 0.0243 - accuracy: 0.9922 - val_loss: 0.0229 - val_accuracy: 0.9928 - lr: 0.0010
# Epoch 25/30
# 934/934 [==============================] - 2s 2ms/step - loss: 0.0236 - accuracy: 0.9926 - val_loss: 0.0286 - val_accuracy: 0.9915 - lr: 0.0010
# Epoch 26/30
# 934/934 [==============================] - 2s 2ms/step - loss: 0.0237 - accuracy: 0.9924 - val_loss: 0.0261 - val_accuracy: 0.9910 - lr: 0.0010
# Epoch 27/30
# 934/934 [==============================] - 2s 2ms/step - loss: 0.0235 - accuracy: 0.9924 - val_loss: 0.0216 - val_accuracy: 0.9933 - lr: 0.0010
# Epoch 28/30
# 934/934 [==============================] - 1s 2ms/step - loss: 0.0225 - accuracy: 0.9929 - val_loss: 0.0220 - val_accuracy: 0.9933 - lr: 0.0010
# Epoch 29/30
# 934/934 [==============================] - 2s 2ms/step - loss: 0.0251 - accuracy: 0.9928 - val_loss: 0.0324 - val_accuracy: 0.9905 - lr: 0.0010
# Epoch 30/30
# 934/934 [==============================] - 2s 2ms/step - loss: 0.0225 - accuracy: 0.9930 - val_loss: 0.0318 - val_accuracy: 0.9898 - lr: 0.0010

# %%
# ----------------------------------------------------------------------
# 7⃣  Evaluation
# ----------------------------------------------------------------------
print("[INFO] Evaluating student …")
loss, acc = student.evaluate(X_test_s, y_test_o, verbose=0)
print(f"[RESULT] TEST – Loss: {loss:.4f} | Accuracy: {acc:.4f}\n")

y_pred = np.argmax(student.predict(X_test_s, verbose=0), axis=1)
print(classification_report(y_test, y_pred, target_names=le.classes_))
print(confusion_matrix(y_test, y_pred))
# Out:
# [INFO] Evaluating student …
# [RESULT] TEST – Loss: 0.5899 | Accuracy: 0.8744
#
#               precision    recall  f1-score   support
#
#        fraud       0.90      0.83      0.86      1269
#        licit       0.86      0.92      0.89      1430
#
#     accuracy                           0.87      2699
#    macro avg       0.88      0.87      0.87      2699
# weighted avg       0.88      0.87      0.87      2699
#
# [[1050  219]
#  [ 120 1310]]

# %%
_ = student.predict(X_comb_s[:1])  # oppure: student(X_comb_s[:1], training=False)

# ----------------------------------------------------------------------
# 8⃣  Symbolic Rule Extraction with DEXiRE
# ----------------------------------------------------------------------
print("[INFO] Extracting rules with DEXiRE … (this may take a while)")

# Build DataFrame of scaled features for DEXiRE
features_df = pd.DataFrame(X_comb_s, columns=feature_names)

dexire = DEXiRE(model=student, class_names=le.classes_.tolist())
rules_raw = dexire.extract_rules(features_df, y_comb)

# Save raw rules
rules_path = Path("rules_student.txt")
rules_path.write_text(str(rules_raw), encoding="utf-8")
print(f"[INFO] Raw rules saved → {rules_path}")

# Prettify placeholders (X_i) with real feature names
idx2name = {i: name for i, name in enumerate(feature_names)}

def repl(match):
    return idx2name.get(int(match.group(1)), match.group(0))

rules_pretty = re.sub(r"X_(\d+)", repl, str(rules_raw))
pretty_path = Path("rules_student_pretty.txt")
pretty_path.write_text(rules_pretty, encoding="utf-8")
print(f"[INFO] Pretty rules saved → {pretty_path}")
# Out:
# 1/1 [==============================] - 0s 11ms/step
# [INFO] Extracting rules with DEXiRE … (this may take a while)
# 37328/37328 [==============================] - 9s 233us/step
# Unique predictions: [0 1]
# 37328/37328 [==============================] - 8s 209us/step
# 73
# feature_73
# Symbolic expression: feature_73 <= 0.5
# 30
# feature_30
# Symbolic expression: feature_30 <= 0.5
# 47
# feature_47
# Symbolic expression: feature_47 <= 0.5
# 7
# feature_7
# Symbolic expression: feature_7 <= 0.5
# 52
# feature_52
# Symbolic expression: feature_52 <= 0.5
# 110
# feature_110
# Symbolic expression: feature_110 <= 0.5
# 19
# feature_19
# Symbolic expression: feature_19 <= 0.5
# 59
# feature_59
# Symbolic expression: feature_59 <= 0.5
# 80
# feature_80
# Symbolic expression: feature_80 <= 0.5
# 26
# feature_26
# Symbolic expression: feature_26 <= 0.5
# 99
# feature_99
# Symbolic expression: feature_99 <= 0.5
# 62
# feature_62
# Symbolic expression: feature_62 <= 0.5
# Symbolic expression: feature_62 > 0.5
# Symbolic expression: feature_99 > 0.5
# Symbolic expression: feature_26 > 0.5
# Symbolic expression: feature_80 > 0.5
# Symbolic expression: feature_59 > 0.5
# Symbolic expression: feature_19 > 0.5
# Symbolic expression: feature_110 > 0.5
# Symbolic expression: feature_52 > 0.5
# Symbolic expression: feature_7 > 0.5
# Symbolic expression: feature_47 > 0.5
# 52
# feature_52
# Symbolic expression: feature_52 <= 0.5
# 41
# feature_41
# Symbolic expression: feature_41 <= 0.5
# 104
# feature_104
# Symbolic expression: feature_104 <= 0.5
# 106
# feature_106
# Symbolic expression: feature_106 <= 0.5
# Symbolic expression: feature_106 > 0.5
# Symbolic expression: feature_104 > 0.5
# Symbolic expression: feature_41 > 0.5
# Symbolic expression: feature_52 > 0.5
# Symbolic expression: feature_30 > 0.5
# 5
# feature_5
# Symbolic expression: feature_5 <= 0.5
# 13
# feature_13
# Symbolic expression: feature_13 <= 0.5
# 103
# feature_103
# Symbolic expression: feature_103 <= 0.5
# Symbolic expression: feature_103 > 0.5
# Symbolic expression: feature_13 > 0.5
# Symbolic expression: feature_5 > 0.5
# Symbolic expression: feature_73 > 0.5
# 50
# feature_50
# Symbolic expression: feature_50 <= 0.5
# 66
# feature_66
# Symbolic expression: feature_66 <= 0.5
# 54
# feature_54
# Symbolic expression: feature_54 <= 0.5
# 95
# feature_95
# Symbolic expression: feature_95 <= 0.5
# 76
# feature_76
# Symbolic expression: feature_76 <= 0.5
# 118
# feature_118
# Symbolic expression: feature_118 <= 0.5
# Symbolic expression: feature_118 > 0.5
# 58
# feature_58
# Symbolic expression: feature_58 <= 0.5
# 85
# feature_85
# Symbolic expression: feature_85 <= 0.5
# 16
# feature_16
# Symbolic expression: feature_16 <= 0.5
# Symbolic expression: feature_16 > 0.5
# Symbolic expression: feature_85 > 0.5
# Symbolic expression: feature_58 > 0.5
# Symbolic expression: feature_76 > 0.5
# Symbolic expression: feature_95 > 0.5
# Symbolic expression: feature_54 > 0.5
# Symbolic expression: feature_66 > 0.5
# Symbolic expression: feature_50 > 0.5
# 18
# X_18
# Symbolic expression: X_18 <= -0.127
# 14
# X_14
# Symbolic expression: X_14 <= 0.297
# 11
# X_11
# Symbolic expression: X_11 <= -0.294
# Symbolic expression: X_11 > -0.294
# 0
# X_0
# Symbolic expression: X_0 <= -0.216
# Symbolic expression: X_0 > -0.216
# 11
# X_11
# Symbolic expression: X_11 <= -0.082
# Symbolic expression: X_11 > -0.082
# 11
# X_11
# Symbolic expression: X_11 <= 0.319
# Symbolic expression: X_11 > 0.319
# Symbolic expression: X_14 > 0.297
# 13
# X_13
# Symbolic expression: X_13 <= 0.043
# Symbolic expression: X_13 > 0.043
# 16
# X_16
# Symbolic expression: X_16 <= -2.701
# Symbolic expression: X_16 > -2.701
# 19
# X_19
# Symbolic expression: X_19 <= -0.027
# Symbolic expression: X_19 > -0.027
# 20
# X_20
# Symbolic expression: X_20 <= 1.018
# 16
# X_16
# Symbolic expression: X_16 <= 0.138
# Symbolic expression: X_16 > 0.138
# 9
# X_9
# Symbolic expression: X_9 <= 1.538
# 14
# X_14
# Symbolic expression: X_14 <= 0.516
# Symbolic expression: X_14 > 0.516
# 17
# X_17
# Symbolic expression: X_17 <= 6.29
# 13
# X_13
# Symbolic expression: X_13 <= 0.201
# Symbolic expression: X_13 > 0.201
# 20
# X_20
# Symbolic expression: X_20 <= 0.68
# 9
# X_9
# Symbolic expression: X_9 <= 0.712
# 14
# X_14
# Symbolic expression: X_14 <= 0.693
# Symbolic expression: X_14 > 0.693
# 13
# X_13
# Symbolic expression: X_13 <= 0.284
# Symbolic expression: X_13 > 0.284
# 14
# X_14
# Symbolic expression: X_14 <= 0.713
# Symbolic expression: X_14 > 0.713
# 0
# X_0
# Symbolic expression: X_0 <= 0.394
# Symbolic expression: X_0 > 0.394
# Symbolic expression: X_9 > 0.712
# Symbolic expression: X_20 > 0.68
# Symbolic expression: X_17 > 6.29
# Symbolic expression: X_9 > 1.538
# Symbolic expression: X_20 > 1.018
# Symbolic expression: X_18 > -0.127
# 19
# X_19
# Symbolic expression: X_19 <= -0.022
# 3
# X_3
# Symbolic expression: X_3 <= -0.167
# 14
# X_14
# Symbolic expression: X_14 <= 0.226
# 0
# X_0
# Symbolic expression: X_0 <= 1.195
# 20
# X_20
# Symbolic expression: X_20 <= 2.468
# 0
# X_0
# Symbolic expression: X_0 <= -0.178
# 14
# X_14
# Symbolic expression: X_14 <= -0.046
# 13
# X_13
# Symbolic expression: X_13 <= -2.757
# Symbolic expression: X_13 > -2.757
# 9
# X_9
# Symbolic expression: X_9 <= 3.815
# 7
# X_7
# Symbolic expression: X_7 <= 0.007
# 15
# X_15
# Symbolic expression: X_15 <= 1.372
# 11
# X_11
# Symbolic expression: X_11 <= 1.6
# 14
# X_14
# Symbolic expression: X_14 <= -0.168
# 6
# X_6
# Symbolic expression: X_6 <= 0.194
# 9
# X_9
# Symbolic expression: X_9 <= 3.148
# 7
# X_7
# Symbolic expression: X_7 <= -0.051
# 11
# X_11
# Symbolic expression: X_11 <= 0.141
# 3
# X_3
# Symbolic expression: X_3 <= -0.21
# 8
# X_8
# Symbolic expression: X_8 <= 0.188
# 13
# X_13
# Symbolic expression: X_13 <= -2.692
# Symbolic expression: X_13 > -2.692
# 14
# X_14
# Symbolic expression: X_14 <= -0.335
# 9
# X_9
# Symbolic expression: X_9 <= 1.645
# 1
# X_1
# Symbolic expression: X_1 <= -0.121
# 3
# X_3
# Symbolic expression: X_3 <= -0.214
# 13
# X_13
# Symbolic expression: X_13 <= -2.513
# Symbolic expression: X_13 > -2.513
# 17
# X_17
# Symbolic expression: X_17 <= -0.122
# 2
# X_2
# Symbolic expression: X_2 <= -0.02
# 11
# X_11
# Symbolic expression: X_11 <= 0.092
# 2
# X_2
# Symbolic expression: X_2 <= -0.026
# Symbolic expression: X_2 > -0.026
# Symbolic expression: X_11 > 0.092
# Symbolic expression: X_2 > -0.02
# Symbolic expression: X_17 > -0.122
# Symbolic expression: X_3 > -0.214
# Symbolic expression: X_1 > -0.121
# Symbolic expression: X_9 > 1.645
# Symbolic expression: X_14 > -0.335
# Symbolic expression: X_8 > 0.188
# Symbolic expression: X_3 > -0.21
# Symbolic expression: X_11 > 0.141
# Symbolic expression: X_7 > -0.051
# Symbolic expression: X_9 > 3.148
# Symbolic expression: X_6 > 0.194
# Symbolic expression: X_14 > -0.168
# Symbolic expression: X_11 > 1.6
# Symbolic expression: X_15 > 1.372
# Symbolic expression: X_7 > 0.007
# Symbolic expression: X_9 > 3.815
# Symbolic expression: X_14 > -0.046
# Symbolic expression: X_0 > -0.178
# Symbolic expression: X_20 > 2.468
# Symbolic expression: X_0 > 1.195
# Symbolic expression: X_14 > 0.226
# Symbolic expression: X_3 > -0.167
# Symbolic expression: X_19 > -0.022
# 8
# X_8
# Symbolic expression: X_8 <= -0.153
# Symbolic expression: X_8 > -0.153
# Unique predictions: [0 1]
# 37328/37328 [==============================] - 8s 218us/step
# 50
# feature_50
# Symbolic expression: feature_50 <= 0.5
# 5
# feature_5
# Symbolic expression: feature_5 <= 0.5
# 6
# feature_6
# Symbolic expression: feature_6 <= 0.5
# 40
# feature_40
# Symbolic expression: feature_40 <= 0.5
# 39
# feature_39
# Symbolic expression: feature_39 <= 0.5
# 33
# feature_33
# Symbolic expression: feature_33 <= 0.5
# 14
# feature_14
# Symbolic expression: feature_14 <= 0.5
# 3
# feature_3
# Symbolic expression: feature_3 <= 0.5
# 58
# feature_58
# Symbolic expression: feature_58 <= 0.5
# 4
# feature_4
# Symbolic expression: feature_4 <= 0.5
# 56
# feature_56
# Symbolic expression: feature_56 <= 0.5
# 17
# feature_17
# Symbolic expression: feature_17 <= 0.5
# 36
# feature_36
# Symbolic expression: feature_36 <= 0.5
# Symbolic expression: feature_36 > 0.5
# Symbolic expression: feature_17 > 0.5
# Symbolic expression: feature_56 > 0.5
# Symbolic expression: feature_4 > 0.5
# Symbolic expression: feature_58 > 0.5
# Symbolic expression: feature_3 > 0.5
# Symbolic expression: feature_14 > 0.5
# Symbolic expression: feature_33 > 0.5
# Symbolic expression: feature_39 > 0.5
# Symbolic expression: feature_40 > 0.5
# Symbolic expression: feature_6 > 0.5
# Symbolic expression: feature_5 > 0.5
# 6
# feature_6
# Symbolic expression: feature_6 <= 0.5
# Symbolic expression: feature_6 > 0.5
# 40
# feature_40
# Symbolic expression: feature_40 <= 0.5
# Symbolic expression: feature_40 > 0.5
# Symbolic expression: feature_50 > 0.5
# 38
# feature_38
# Symbolic expression: feature_38 <= 0.5
# 54
# feature_54
# Symbolic expression: feature_54 <= 0.5
# 34
# feature_34
# Symbolic expression: feature_34 <= 0.5
# 1
# feature_1
# Symbolic expression: feature_1 <= 0.5
# 23
# feature_23
# Symbolic expression: feature_23 <= 0.5
# 29
# feature_29
# Symbolic expression: feature_29 <= 0.5
# 0
# feature_0
# Symbolic expression: feature_0 <= 0.5
# 37
# feature_37
# Symbolic expression: feature_37 <= 0.5
# 25
# feature_25
# Symbolic expression: feature_25 <= 0.5
# Symbolic expression: feature_25 > 0.5
# 48
# feature_48
# Symbolic expression: feature_48 <= 0.5
# 9
# feature_9
# Symbolic expression: feature_9 <= 0.5
# 47
# feature_47
# Symbolic expression: feature_47 <= 0.5
# 18
# feature_18
# Symbolic expression: feature_18 <= 0.5
# 52
# feature_52
# Symbolic expression: feature_52 <= 0.5
# 35
# feature_35
# Symbolic expression: feature_35 <= 0.5
# 17
# feature_17
# Symbolic expression: feature_17 <= 0.5
# Symbolic expression: feature_17 > 0.5
# 39
# feature_39
# Symbolic expression: feature_39 <= 0.5
# Symbolic expression: feature_39 > 0.5
# 30
# feature_30
# Symbolic expression: feature_30 <= 0.5
# 59
# feature_59
# Symbolic expression: feature_59 <= 0.5
# Symbolic expression: feature_59 > 0.5
# Symbolic expression: feature_30 > 0.5
# Symbolic expression: feature_35 > 0.5
# Symbolic expression: feature_52 > 0.5
# Symbolic expression: feature_18 > 0.5
# Symbolic expression: feature_47 > 0.5
# Symbolic expression: feature_9 > 0.5
# Symbolic expression: feature_48 > 0.5
# Symbolic expression: feature_37 > 0.5
# Symbolic expression: feature_0 > 0.5
# Symbolic expression: feature_29 > 0.5
# Symbolic expression: feature_23 > 0.5
# Symbolic expression: feature_1 > 0.5
# Symbolic expression: feature_34 > 0.5
# Symbolic expression: feature_54 > 0.5
# Symbolic expression: feature_38 > 0.5
# 18
# X_18
# Symbolic expression: X_18 <= -0.127
# 11
# X_11
# Symbolic expression: X_11 <= -0.303
# 14
# X_14
# Symbolic expression: X_14 <= 0.678
# Symbolic expression: X_14 > 0.678
# 13
# X_13
# Symbolic expression: X_13 <= -0.975
# Symbolic expression: X_13 > -0.975
# 16
# X_16
# Symbolic expression: X_16 <= -1.469
# Symbolic expression: X_16 > -1.469
# 5
# X_5
# Symbolic expression: X_5 <= -0.182
# Symbolic expression: X_5 > -0.182
# 9
# X_9
# Symbolic expression: X_9 <= 0.043
# 10
# X_10
# Symbolic expression: X_10 <= -0.151
# 19
# X_19
# Symbolic expression: X_19 <= -0.024
# 0
# X_0
# Symbolic expression: X_0 <= -0.484
# Symbolic expression: X_0 > -0.484
# Symbolic expression: X_19 > -0.024
# 0
# X_0
# Symbolic expression: X_0 <= -0.25
# 20
# X_20
# Symbolic expression: X_20 <= 0.138
# 4
# X_4
# Symbolic expression: X_4 <= -0.022
# Symbolic expression: X_4 > -0.022
# 14
# X_14
# Symbolic expression: X_14 <= 0.742
# Symbolic expression: X_14 > 0.742
# 8
# X_8
# Symbolic expression: X_8 <= -0.153
# Symbolic expression: X_8 > -0.153
# 13
# X_13
# Symbolic expression: X_13 <= -0.731
# Symbolic expression: X_13 > -0.731
# Symbolic expression: X_20 > 0.138
# Symbolic expression: X_0 > -0.25
# Symbolic expression: X_10 > -0.151
# Symbolic expression: X_9 > 0.043
# Symbolic expression: X_11 > -0.303
# 2
# X_2
# Symbolic expression: X_2 <= -0.481
# Symbolic expression: X_2 > -0.481
# 0
# X_0
# Symbolic expression: X_0 <= -0.09
# Symbolic expression: X_0 > -0.09
# 11
# X_11
# Symbolic expression: X_11 <= -0.183
# Symbolic expression: X_11 > -0.183
# 13
# X_13
# Symbolic expression: X_13 <= 0.637
# 9
# X_9
# Symbolic expression: X_9 <= 7.726
# 0
# X_0
# Symbolic expression: X_0 <= -0.08
# Symbolic expression: X_0 > -0.08
# Symbolic expression: X_9 > 7.726
# Symbolic expression: X_13 > 0.637
# Symbolic expression: X_18 > -0.127
# 19
# X_19
# Symbolic expression: X_19 <= -0.022
# 3
# X_3
# Symbolic expression: X_3 <= -0.16
# 20
# X_20
# Symbolic expression: X_20 <= 1.189
# 0
# X_0
# Symbolic expression: X_0 <= 0.347
# 20
# X_20
# Symbolic expression: X_20 <= 0.201
# 18
# X_18
# Symbolic expression: X_18 <= 9.943
# 8
# X_8
# Symbolic expression: X_8 <= 0.072
# 4
# X_4
# Symbolic expression: X_4 <= -0.026
# Symbolic expression: X_4 > -0.026
# 14
# X_14
# Symbolic expression: X_14 <= 1.186
# 2
# X_2
# Symbolic expression: X_2 <= -0.431
# 18
# X_18
# Symbolic expression: X_18 <= 5.251
# 14
# X_14
# Symbolic expression: X_14 <= 0.815
# 10
# X_10
# Symbolic expression: X_10 <= -0.153
# Symbolic expression: X_10 > -0.153
# 18
# X_18
# Symbolic expression: X_18 <= 3.198
# 11
# X_11
# Symbolic expression: X_11 <= 1.4
# 9
# X_9
# Symbolic expression: X_9 <= 16.816
# 14
# X_14
# Symbolic expression: X_14 <= 0.693
# 20
# X_20
# Symbolic expression: X_20 <= 0.086
# 9
# X_9
# Symbolic expression: X_9 <= 1.538
# 10
# X_10
# Symbolic expression: X_10 <= -0.153
# Symbolic expression: X_10 > -0.153
# 11
# X_11
# Symbolic expression: X_11 <= 0.826
# 5
# X_5
# Symbolic expression: X_5 <= -0.07
# 20
# X_20
# Symbolic expression: X_20 <= -0.064
# 8
# X_8
# Symbolic expression: X_8 <= -0.034
# 14
# X_14
# Symbolic expression: X_14 <= 0.614
# 11
# X_11
# Symbolic expression: X_11 <= -0.118
# 3
# X_3
# Symbolic expression: X_3 <= -0.178
# 2
# X_2
# Symbolic expression: X_2 <= -0.432
# 9
# X_9
# Symbolic expression: X_9 <= 1.3
# 15
# X_15
# Symbolic expression: X_15 <= -0.03
# 19
# X_19
# Symbolic expression: X_19 <= -0.023
# 14
# X_14
# Symbolic expression: X_14 <= 0.501
# 13
# X_13
# Symbolic expression: X_13 <= 0.676
# 14
# X_14
# Symbolic expression: X_14 <= 0.453
# Symbolic expression: X_14 > 0.453
# Symbolic expression: X_13 > 0.676
# Symbolic expression: X_14 > 0.501
# Symbolic expression: X_19 > -0.023
# Symbolic expression: X_15 > -0.03
# Symbolic expression: X_9 > 1.3
# Symbolic expression: X_2 > -0.432
# Symbolic expression: X_3 > -0.178
# Symbolic expression: X_11 > -0.118
# Symbolic expression: X_14 > 0.614
# Symbolic expression: X_8 > -0.034
# Symbolic expression: X_20 > -0.064
# Symbolic expression: X_5 > -0.07
# Symbolic expression: X_11 > 0.826
# Symbolic expression: X_9 > 1.538
# Symbolic expression: X_20 > 0.086
# Symbolic expression: X_14 > 0.693
# Symbolic expression: X_9 > 16.816
# Symbolic expression: X_11 > 1.4
# Symbolic expression: X_18 > 3.198
# Symbolic expression: X_14 > 0.815
# Symbolic expression: X_18 > 5.251
# Symbolic expression: X_2 > -0.431
# 14
# X_14
# Symbolic expression: X_14 <= -1.852
# Symbolic expression: X_14 > -1.852
# Symbolic expression: X_14 > 1.186
# Symbolic expression: X_8 > 0.072
# Symbolic expression: X_18 > 9.943
# Symbolic expression: X_20 > 0.201
# Symbolic expression: X_0 > 0.347
# Symbolic expression: X_20 > 1.189
# Symbolic expression: X_3 > -0.16
# Symbolic expression: X_19 > -0.022
# 8
# X_8
# Symbolic expression: X_8 <= -0.153
# Symbolic expression: X_8 > -0.153
# Unique predictions: [0 1]
# 37328/37328 [==============================] - 9s 233us/step
# 27
# feature_27
# Symbolic expression: feature_27 <= 0.5
# 25
# feature_25
# Symbolic expression: feature_25 <= 0.5
# 15
# feature_15
# Symbolic expression: feature_15 <= 0.5
# 2
# feature_2
# Symbolic expression: feature_2 <= 0.5
# 0
# feature_0
# Symbolic expression: feature_0 <= 0.5
# 11
# feature_11
# Symbolic expression: feature_11 <= 0.5
# 19
# feature_19
# Symbolic expression: feature_19 <= 0.5
# 20
# feature_20
# Symbolic expression: feature_20 <= 0.5
# 16
# feature_16
# Symbolic expression: feature_16 <= 0.5
# 7
# feature_7
# Symbolic expression: feature_7 <= 0.5
# 31
# feature_31
# Symbolic expression: feature_31 <= 0.5
# 13
# feature_13
# Symbolic expression: feature_13 <= 0.5
# 23
# feature_23
# Symbolic expression: feature_23 <= 0.5
# 10
# feature_10
# Symbolic expression: feature_10 <= 0.5
# 24
# feature_24
# Symbolic expression: feature_24 <= 0.5
# Symbolic expression: feature_24 > 0.5
# Symbolic expression: feature_10 > 0.5
# 4
# feature_4
# Symbolic expression: feature_4 <= 0.5
# Symbolic expression: feature_4 > 0.5
# 5
# feature_5
# Symbolic expression: feature_5 <= 0.5
# Symbolic expression: feature_5 > 0.5
# Symbolic expression: feature_23 > 0.5
# Symbolic expression: feature_13 > 0.5
# Symbolic expression: feature_31 > 0.5
# Symbolic expression: feature_7 > 0.5
# Symbolic expression: feature_16 > 0.5
# Symbolic expression: feature_20 > 0.5
# Symbolic expression: feature_19 > 0.5
# Symbolic expression: feature_11 > 0.5
# Symbolic expression: feature_0 > 0.5
# Symbolic expression: feature_2 > 0.5
# Symbolic expression: feature_15 > 0.5
# Symbolic expression: feature_25 > 0.5
# Symbolic expression: feature_27 > 0.5
# 0
# feature_0
# Symbolic expression: feature_0 <= 0.5
# Symbolic expression: feature_0 > 0.5
# 25
# feature_25
# Symbolic expression: feature_25 <= 0.5
# Symbolic expression: feature_25 > 0.5
# 18
# X_18
# Symbolic expression: X_18 <= -0.127
# 11
# X_11
# Symbolic expression: X_11 <= -0.309
# 14
# X_14
# Symbolic expression: X_14 <= 0.491
# Symbolic expression: X_14 > 0.491
# 13
# X_13
# Symbolic expression: X_13 <= -0.581
# Symbolic expression: X_13 > -0.581
# 16
# X_16
# Symbolic expression: X_16 <= -1.473
# Symbolic expression: X_16 > -1.473
# 2
# X_2
# Symbolic expression: X_2 <= -0.485
# Symbolic expression: X_2 > -0.485
# 9
# X_9
# Symbolic expression: X_9 <= -0.185
# 3
# X_3
# Symbolic expression: X_3 <= -0.269
# Symbolic expression: X_3 > -0.269
# 18
# X_18
# Symbolic expression: X_18 <= -0.129
# 13
# X_13
# Symbolic expression: X_13 <= 0.201
# Symbolic expression: X_13 > 0.201
# 0
# X_0
# Symbolic expression: X_0 <= 4.669
# 5
# X_5
# Symbolic expression: X_5 <= -0.182
# Symbolic expression: X_5 > -0.182
# 9
# X_9
# Symbolic expression: X_9 <= -0.259
# 16
# X_16
# Symbolic expression: X_16 <= -1.305
# Symbolic expression: X_16 > -1.305
# 20
# X_20
# Symbolic expression: X_20 <= -0.525
# 10
# X_10
# Symbolic expression: X_10 <= -0.153
# 14
# X_14
# Symbolic expression: X_14 <= 0.943
# Symbolic expression: X_14 > 0.943
# 4
# X_4
# Symbolic expression: X_4 <= 543.604
# 17
# X_17
# Symbolic expression: X_17 <= 52.151
# 5
# X_5
# Symbolic expression: X_5 <= -0.182
# Symbolic expression: X_5 > -0.182
# 5
# X_5
# Symbolic expression: X_5 <= -0.182
# Symbolic expression: X_5 > -0.182
# 14
# X_14
# Symbolic expression: X_14 <= 1.188
# Symbolic expression: X_14 > 1.188
# 16
# X_16
# Symbolic expression: X_16 <= -1.213
# Symbolic expression: X_16 > -1.213
# 13
# X_13
# Symbolic expression: X_13 <= 0.283
# Symbolic expression: X_13 > 0.283
# 17
# X_17
# Symbolic expression: X_17 <= -0.122
# Symbolic expression: X_17 > -0.122
# 5
# X_5
# Symbolic expression: X_5 <= -0.182
# Symbolic expression: X_5 > -0.182
# 13
# X_13
# Symbolic expression: X_13 <= 0.402
# Symbolic expression: X_13 > 0.402
# 2
# X_2
# Symbolic expression: X_2 <= -0.457
# 4
# X_4
# Symbolic expression: X_4 <= -0.026
# Symbolic expression: X_4 > -0.026
# 15
# X_15
# Symbolic expression: X_15 <= -0.032
# 13
# X_13
# Symbolic expression: X_13 <= 0.655
# Symbolic expression: X_13 > 0.655
# Symbolic expression: X_15 > -0.032
# Symbolic expression: X_2 > -0.457
# Symbolic expression: X_17 > 52.151
# Symbolic expression: X_4 > 543.604
# Symbolic expression: X_10 > -0.153
# Symbolic expression: X_20 > -0.525
# Symbolic expression: X_9 > -0.259
# Symbolic expression: X_0 > 4.669
# Symbolic expression: X_18 > -0.129
# Symbolic expression: X_9 > -0.185
# Symbolic expression: X_11 > -0.309
# 2
# X_2
# Symbolic expression: X_2 <= -0.481
# Symbolic expression: X_2 > -0.481
# 2
# X_2
# Symbolic expression: X_2 <= -0.475
# Symbolic expression: X_2 > -0.475
# 9
# X_9
# Symbolic expression: X_9 <= -0.264
# Symbolic expression: X_9 > -0.264
# 2
# X_2
# Symbolic expression: X_2 <= 18.243
# 0
# X_0
# Symbolic expression: X_0 <= -0.37
# Symbolic expression: X_0 > -0.37
# 2
# X_2
# Symbolic expression: X_2 <= 8.632
# 11
# X_11
# Symbolic expression: X_11 <= 27.408
# 11
# X_11
# Symbolic expression: X_11 <= -0.29
# Symbolic expression: X_11 > -0.29
# 15
# X_15
# Symbolic expression: X_15 <= 1.572
# 11
# X_11
# Symbolic expression: X_11 <= -0.247
# Symbolic expression: X_11 > -0.247
# 20
# X_20
# Symbolic expression: X_20 <= -0.562
# Symbolic expression: X_20 > -0.562
# 2
# X_2
# Symbolic expression: X_2 <= -0.37
# Symbolic expression: X_2 > -0.37
# 2
# X_2
# Symbolic expression: X_2 <= 8.059
# 9
# X_9
# Symbolic expression: X_9 <= -0.259
# Symbolic expression: X_9 > -0.259
# 11
# X_11
# Symbolic expression: X_11 <= -0.136
# Symbolic expression: X_11 > -0.136
# 0
# X_0
# Symbolic expression: X_0 <= -0.341
# Symbolic expression: X_0 > -0.341
# 9
# X_9
# Symbolic expression: X_9 <= -0.253
# Symbolic expression: X_9 > -0.253
# Symbolic expression: X_2 > 8.059
# Symbolic expression: X_15 > 1.572
# Symbolic expression: X_11 > 27.408
# Symbolic expression: X_2 > 8.632
# Symbolic expression: X_2 > 18.243
# Symbolic expression: X_18 > -0.127
# 19
# X_19
# Symbolic expression: X_19 <= -0.021
# 3
# X_3
# Symbolic expression: X_3 <= -0.159
# 20
# X_20
# Symbolic expression: X_20 <= 2.452
# 4
# X_4
# Symbolic expression: X_4 <= -0.026
# Symbolic expression: X_4 > -0.026
# 7
# X_7
# Symbolic expression: X_7 <= -0.053
# 0
# X_0
# Symbolic expression: X_0 <= 1.022
# 11
# X_11
# Symbolic expression: X_11 <= 0.008
# 4
# X_4
# Symbolic expression: X_4 <= -0.026
# Symbolic expression: X_4 > -0.026
# 1
# X_1
# Symbolic expression: X_1 <= -0.095
# 14
# X_14
# Symbolic expression: X_14 <= 1.135
# 4
# X_4
# Symbolic expression: X_4 <= -0.026
# Symbolic expression: X_4 > -0.026
# 5
# X_5
# Symbolic expression: X_5 <= -0.064
# 9
# X_9
# Symbolic expression: X_9 <= 11.137
# 9
# X_9
# Symbolic expression: X_9 <= 3.879
# 19
# X_19
# Symbolic expression: X_19 <= -0.022
# 7
# X_7
# Symbolic expression: X_7 <= -0.06
# 14
# X_14
# Symbolic expression: X_14 <= 0.824
# 20
# X_20
# Symbolic expression: X_20 <= 2.404
# 20
# X_20
# Symbolic expression: X_20 <= 1.129
# 5
# X_5
# Symbolic expression: X_5 <= -0.067
# 7
# X_7
# Symbolic expression: X_7 <= -0.064
# 6
# X_6
# Symbolic expression: X_6 <= 0.155
# 14
# X_14
# Symbolic expression: X_14 <= 0.631
# 2
# X_2
# Symbolic expression: X_2 <= 1.868
# 11
# X_11
# Symbolic expression: X_11 <= -0.001
# 3
# X_3
# Symbolic expression: X_3 <= -0.16
# 6
# X_6
# Symbolic expression: X_6 <= -0.044
# 0
# X_0
# Symbolic expression: X_0 <= -0.342
# 18
# X_18
# Symbolic expression: X_18 <= -0.127
# Symbolic expression: X_18 > -0.127
# 6
# X_6
# Symbolic expression: X_6 <= -0.065
# 13
# X_13
# Symbolic expression: X_13 <= 0.775
# 3
# X_3
# Symbolic expression: X_3 <= -0.176
# 8
# X_8
# Symbolic expression: X_8 <= -0.112
# 0
# X_0
# Symbolic expression: X_0 <= -0.354
# 11
# X_11
# Symbolic expression: X_11 <= -0.201
# Symbolic expression: X_11 > -0.201
# Symbolic expression: X_0 > -0.354
# Symbolic expression: X_8 > -0.112
# Symbolic expression: X_3 > -0.176
# Symbolic expression: X_13 > 0.775
# Symbolic expression: X_6 > -0.065
# Symbolic expression: X_0 > -0.342
# Symbolic expression: X_6 > -0.044
# Symbolic expression: X_3 > -0.16
# Symbolic expression: X_11 > -0.001
# Symbolic expression: X_2 > 1.868
# Symbolic expression: X_14 > 0.631
# Symbolic expression: X_6 > 0.155
# Symbolic expression: X_7 > -0.064
# Symbolic expression: X_5 > -0.067
# Symbolic expression: X_20 > 1.129
# Symbolic expression: X_20 > 2.404
# Symbolic expression: X_14 > 0.824
# Symbolic expression: X_7 > -0.06
# Symbolic expression: X_19 > -0.022
# Symbolic expression: X_9 > 3.879
# Symbolic expression: X_9 > 11.137
# Symbolic expression: X_5 > -0.064
# Symbolic expression: X_14 > 1.135
# Symbolic expression: X_1 > -0.095
# Symbolic expression: X_11 > 0.008
# Symbolic expression: X_0 > 1.022
# Symbolic expression: X_7 > -0.053
# Symbolic expression: X_20 > 2.452
# Symbolic expression: X_3 > -0.159
# Symbolic expression: X_19 > -0.021
# 8
# X_8
# Symbolic expression: X_8 <= -0.153
# Symbolic expression: X_8 > -0.153
# total rules: [IF ((X_18 > -0.127) AND (X_19 <= -0.022) AND (X_3 <= -0.167) AND (X_14 <= 0.226) AND (X_0 <= 1.195) AND (X_20 <= 2.468) AND (X_0 <= -0.178) AND (X_14 <= -0.046) AND (X_13 > -2.757) AND (X_9 <= 3.815) AND (X_7 <= 0.007) AND (X_15 <= 1.372) AND (X_11 <= 1.6) AND (X_14 <= -0.168) AND (X_6 <= 0.194) AND (X_9 <= 3.148) AND (X_7 <= -0.051) AND (X_11 <= 0.141) AND (X_3 <= -0.21) AND (X_8 <= 0.188) AND (X_13 > -2.692) AND (X_14 <= -0.335) AND (X_9 <= 1.645) AND (X_1 <= -0.121) AND (X_3 <= -0.214) AND (X_13 > -2.513) AND (X_17 <= -0.122) AND (X_2 <= -0.02) AND (X_11 <= 0.092) AND (X_2 <= -0.026)) THEN fraud, IF ((X_18 <= -0.127) AND (X_14 > 0.297) AND (X_13 > 0.043) AND (X_16 > -2.701) AND (X_19 > -0.027) AND (X_20 <= 1.018) AND (X_16 > 0.138) AND (X_9 <= 1.538) AND (X_14 > 0.516) AND (X_17 <= 6.29) AND (X_13 > 0.201) AND (X_20 <= 0.68) AND (X_9 <= 0.712) AND (X_14 > 0.693) AND (X_13 > 0.284) AND (X_14 > 0.713) AND (X_0 <= 0.394)) THEN licit, IF ((X_18 > -0.127) AND (X_19 > -0.022) AND (X_8 > -0.153)) THEN licit, IF ((X_18 <= -0.127) AND (X_14 > 0.297) AND (X_13 > 0.043) AND (X_16 > -2.701) AND (X_19 <= -0.027)) THEN licit, IF ((X_18 > -0.127) AND (X_19 <= -0.022) AND (X_3 <= -0.167) AND (X_14 > 0.226)) THEN fraud, IF ((X_18 <= -0.127) AND (X_14 <= 0.297) AND (X_11 > -0.294) AND (X_0 > -0.216) AND (X_11 > -0.082) AND (X_11 > 0.319)) THEN licit, IF ((X_18 > -0.127) AND (X_19 <= -0.022) AND (X_3 <= -0.167) AND (X_14 <= 0.226) AND (X_0 <= 1.195) AND (X_20 <= 2.468) AND (X_0 > -0.178)) THEN fraud, IF ((X_18 <= -0.127) AND (X_14 <= 0.297) AND (X_11 <= -0.294)) THEN fraud, IF ((X_18 <= -0.127) AND (X_14 > 0.297) AND (X_13 <= 0.043)) THEN licit, IF ((X_18 > -0.127) AND (X_19 <= -0.022) AND (X_3 > -0.167)) THEN licit, IF ((X_18 > -0.127) AND (X_19 <= -0.022) AND (X_3 <= -0.167) AND (X_14 <= 0.226) AND (X_0 <= 1.195) AND (X_20 <= 2.468) AND (X_0 <= -0.178) AND (X_14 > -0.046)) THEN fraud, IF ((X_18 > -0.127) AND (X_19 <= -0.022) AND (X_3 <= -0.167) AND (X_14 <= 0.226) AND (X_0 <= 1.195) AND (X_20 <= 2.468) AND (X_0 <= -0.178) AND (X_14 <= -0.046) AND (X_13 > -2.757) AND (X_9 <= 3.815) AND (X_7 <= 0.007) AND (X_15 <= 1.372) AND (X_11 <= 1.6) AND (X_14 <= -0.168) AND (X_6 <= 0.194) AND (X_9 <= 3.148) AND (X_7 <= -0.051) AND (X_11 <= 0.141) AND (X_3 <= -0.21) AND (X_8 <= 0.188) AND (X_13 > -2.692) AND (X_14 > -0.335)) THEN fraud, IF ((X_18 <= -0.127) AND (X_14 <= 0.297) AND (X_11 > -0.294) AND (X_0 > -0.216) AND (X_11 > -0.082) AND (X_11 <= 0.319)) THEN licit, IF ((X_18 > -0.127) AND (X_19 <= -0.022) AND (X_3 <= -0.167) AND (X_14 <= 0.226) AND (X_0 <= 1.195) AND (X_20 <= 2.468) AND (X_0 <= -0.178) AND (X_14 <= -0.046) AND (X_13 > -2.757) AND (X_9 <= 3.815) AND (X_7 <= 0.007) AND (X_15 <= 1.372) AND (X_11 <= 1.6) AND (X_14 > -0.168)) THEN fraud, IF ((X_18 <= -0.127) AND (X_14 > 0.297) AND (X_13 > 0.043) AND (X_16 > -2.701) AND (X_19 > -0.027) AND (X_20 <= 1.018) AND (X_16 <= 0.138)) THEN licit, IF ((X_18 <= -0.127) AND (X_14 <= 0.297) AND (X_11 > -0.294) AND (X_0 <= -0.216)) THEN licit, IF ((X_18 <= -0.127) AND (X_14 <= 0.297) AND (X_11 > -0.294) AND (X_0 > -0.216) AND (X_11 <= -0.082)) THEN licit, IF ((X_18 > -0.127) AND (X_19 > -0.022) AND (X_8 <= -0.153)) THEN fraud, IF ((X_18 > -0.127) AND (X_19 <= -0.022) AND (X_3 <= -0.167) AND (X_14 <= 0.226) AND (X_0 <= 1.195) AND (X_20 <= 2.468) AND (X_0 <= -0.178) AND (X_14 <= -0.046) AND (X_13 > -2.757) AND (X_9 <= 3.815) AND (X_7 <= 0.007) AND (X_15 <= 1.372) AND (X_11 <= 1.6) AND (X_14 <= -0.168) AND (X_6 <= 0.194) AND (X_9 <= 3.148) AND (X_7 <= -0.051) AND (X_11 > 0.141)) THEN fraud, IF ((X_18 > -0.127) AND (X_19 <= -0.022) AND (X_3 <= -0.167) AND (X_14 <= 0.226) AND (X_0 <= 1.195) AND (X_20 <= 2.468) AND (X_0 <= -0.178) AND (X_14 <= -0.046) AND (X_13 > -2.757) AND (X_9 <= 3.815) AND (X_7 <= 0.007) AND (X_15 <= 1.372) AND (X_11 <= 1.6) AND (X_14 <= -0.168) AND (X_6 <= 0.194) AND (X_9 <= 3.148) AND (X_7 <= -0.051) AND (X_11 <= 0.141) AND (X_3 <= -0.21) AND (X_8 <= 0.188) AND (X_13 > -2.69 ...
# [INFO] Raw rules saved → rules_student.txt
# [INFO] Pretty rules saved → rules_student_pretty.txt
